# %% [markdown]
# <a href="https://colab.research.google.com/github/AminOcin/cse366_lab3/blob/main/366_lab2_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ![x6.png](data:image/png;base64,...)

# %% [markdown]
# Consider a household trading agent that monitors the price of some commodity, such as toilet paper, by checking for deals online, as well as how much the household has in stock. It must decide whether to order more and how much to order. Assume the percepts are the price and the amount in stock. The command is the number of units the agent decides to order (which is zero if the agent does not order any). A percept trace specifies for each time point (e.g., each day) the price at that time and the amount in stock at that time.

# %% [markdown]
# Utilities

# %%
def argmaxall(gen):
    """gen is a generator of (element,value) pairs, where value is a real.
    argmaxall returns a list of all of the elements with maximal value.
    """
    maxv = -math.inf       # negative infinity
    maxvals = []      # list of maximal elements
    for (e,v) in gen:
        if v>maxv:
            maxvals,maxv = [e], v
        elif v==maxv:
            maxvals.append(e)
    return maxvals

# %%
def argmaxe(gen):
    """gen is a generator of (element,value) pairs, where value is a real.
    argmaxe returns an element with maximal value.
    If there are multiple elements with the max value, one is returned at random.
    """
    return random.choice(argmaxall(gen))

# %%
def argmax(lst):
    """returns maximum index in a list"""
    return argmaxe(enumerate(lst))

# %%
def argmaxd(dct):
   """returns the arg max of a dictionary dct"""
   return argmaxe(dct.items())

# %%
def flip(prob):
    """return true with probability prob"""
    return random.random() < prob

# %%
def select_from_dist(item_prob_dist):
  #{6:0.1, 5:0.1, 4:0.1, 3:0.3, 2:0.2, 1:0.2}
    """ returns a value from a distribution.
    item_prob_dist is an item:probability dictionary, where the
        probabilities sum to 1.
    returns an item chosen in proportion to its probability
    """
    ranreal = random.random()
    for (it,prob) in item_prob_dist.items():
        if ranreal < prob:
            return it
        else:
            ranreal -= prob
    raise RuntimeError(f"{item_prob_dist} is not a probability distribution")

# %% [markdown]
# Display Class

# %%
class Displayable(object):
    """Class that uses 'display'.
    The amount of detail is controlled by max_display_level
    """
    max_display_level = 1   # can be overridden in subclasses or instances

    def display(self,level,*args,**nargs):
        """print the arguments if level is less than or equal to the
        current max_display_level.
        level is an integer.
        the other arguments are whatever arguments print can take.
        """

        if level <= self.max_display_level:
            print(*args, **nargs)  ##if error you are using Python2 not Python3

# %%
class Plot_history(object):
    """Set up the plot for history of price and number in stock"""
    def __init__(self, ag, env):
        self.ag = ag
        self.env = env
        plt.ion()
        plt.xlabel("Time")
        plt.ylabel("Value")


    def plot_env_hist(self):
        """plot history of price and instock"""
        num = len(env.stock_history)
        plt.plot(range(num),env.price_history,label="Price")
        plt.plot(range(num),env.stock_history,label="In stock")
        plt.legend()
        #plt.draw()

    def plot_agent_hist(self):
        """plot history of buying"""
        num = len(ag.buy_history)
        plt.bar(range(1,num+1), ag.buy_history, label="Bought")
        plt.legend()
        #plt.draw()

# %% [markdown]
# Agent Conntroller

# %%
#from display import Displayable

class Agent(Displayable):

    def initial_action(self, percept):
        """return the initial action."""
        return self.select_action(percept)   # same as select_action

    def select_action(self, percept):
        """return the next action (and update internal state) given percept
        percept is variable:value dictionary
        """
        raise NotImplementedError("go")   # abstract method

# %% [markdown]
# Environment

# %%
class Environment(Displayable):
    def initial_percept(self):
        """returns the initial percept for the agent"""
        raise NotImplementedError("initial_percept")   # abstract method

    def do(self, action):
        """does the action in the environment
        returns the next percept """
        raise NotImplementedError("Environment.do")   # abstract method

# %% [markdown]
# Simulate

# %%
class Simulate(Displayable):
    """simulate the interaction between the agent and the environment
    for n time steps.
    Returns a pair of the agent state and the environment state.
    """
    def __init__(self,agent, environment):
        self.agent = agent
        self.env = environment
        self.percept = self.env.initial_percept()
        self.percept_history = [self.percept]
        self.action_history = []

    def go(self, n):
        for i in range(n):
            action = self.agent.select_action(self.percept)
            print(f"i={i} action={action}")

            self.percept = self.env.do(action,i)
            print(f"      percept={self.percept}")

# %% [markdown]
# TP Env

# %%
class TP_env(Environment):
    price_delta = [0, 0, 0, 21, 0, 20, 0, -64, 0, 0, 23, 0, 0, 0, -35,
        0, 76, 0, -41, 0, 0, 0, 21, 0, 5, 0, 5, 0, 0, 0, 5, 0, -15, 0, 5,
       0, 5, 0, -115, 0, 115, 0, 5, 0, -15, 0, 5, 0, 5, 0, 0, 0, 5, 0,
       -59, 0, 44, 0, 5, 0, 5, 0, 0, 0, 5, 0, -65, 50, 0, 5, 0, 5, 0, 0,
       0, 5, 0]
    sd = 5  # noise standard deviation

    def __init__(self):
        """paper buying agent"""
        self.time=0
        self.stock=20
        self.stock_history = []  # memory of the stock history
        self.price_history = []  # memory of the price history

    def initial_percept(self):
        """return initial percept"""
        self.stock_history.append(self.stock)
        self.price = round(234+self.sd*random.gauss(0,1))
        self.price_history.append(self.price)
        #print(f"Initial price: {self.price} ,instock: {self.stock}")
        return {'price': self.price,
                'instock': self.stock}

    def do(self, action, time_unit):
        """does action (buy) and returns percept consisting of price and instock"""
        used = select_from_dist({6:0.1, 5:0.1, 4:0.1, 3:0.3, 2:0.2, 1:0.2})
        print(f"i={time_unit} used={used}")
        # used = select_from_dist({7:0.1, 6:0.2, 5:0.2, 4:0.3, 3:0.1, 2:0.1}) # uses more paper
        bought = action['buy']
        self.stock = self.stock+bought-used
        self.stock_history.append(self.stock)
        self.time += 1
        self.price =  round(self.price
                        + self.price_delta[self.time%len(self.price_delta)] # repeating pattern
                        + self.sd*random.gauss(0,1)) # plus randomness
        self.price_history.append(self.price)
        return {'price': self.price,
                'instock': self.stock}

# %%
class TP_agent(Agent):
    def __init__(self):
        self.spent = 0
        percept = env.initial_percept()
        self.ave = self.last_price = percept['price']
        self.instock = percept['instock']
        self.buy_history = []

    def select_action(self, percept):
        """return next action to carry out
        """
        self.last_price = percept['price']
        self.ave = self.ave+(self.last_price-self.ave)*0.05
        self.instock = percept['instock']
        if self.last_price < 0.7*self.ave and self.instock < 30:
            tobuy = 15
        elif self.instock < 10:
            tobuy = 5
        else:
            tobuy = 0
        self.spent += tobuy*self.last_price
        self.buy_history.append(tobuy)
        #print(f"agent buy:{tobuy}")
        return {'buy': tobuy}

# %%
env = TP_env()
ag = TP_agent()
sim = Simulate(ag,env)
sim.go(10)
ag.spent/env.time
# Out:
# i=0 action={'buy': 0}
# i=0 used=3
#       percept={'price': 223, 'instock': 17}
# i=1 action={'buy': 0}
# i=1 used=2
#       percept={'price': 231, 'instock': 15}
# i=2 action={'buy': 0}
# i=2 used=3
#       percept={'price': 249, 'instock': 12}
# i=3 action={'buy': 0}
# i=3 used=2
#       percept={'price': 247, 'instock': 10}
# i=4 action={'buy': 0}
# i=4 used=3
#       percept={'price': 268, 'instock': 7}
# i=5 action={'buy': 5}
# i=5 used=3
#       percept={'price': 268, 'instock': 9}
# i=6 action={'buy': 5}
# i=6 used=6
#       percept={'price': 212, 'instock': 8}
# i=7 action={'buy': 5}
# i=7 used=5
#       percept={'price': 210, 'instock': 8}
# i=8 action={'buy': 5}
# i=8 used=3
#       percept={'price': 202, 'instock': 10}
# i=9 action={'buy': 0}
# i=9 used=3
#       percept={'price': 222, 'instock': 7}
# 479.0

# %%
sim.go(100);
# Out:
# i=0 action={'buy': 5}
# i=0 used=3
#       percept={'price': 220, 'instock': 9}
# i=1 action={'buy': 5}
# i=1 used=2
#       percept={'price': 221, 'instock': 12}
# i=2 action={'buy': 0}
# i=2 used=2
#       percept={'price': 224, 'instock': 10}
# i=3 action={'buy': 0}
# i=3 used=1
#       percept={'price': 190, 'instock': 9}
# i=4 action={'buy': 5}
# i=4 used=3
#       percept={'price': 195, 'instock': 11}
# i=5 action={'buy': 0}
# i=5 used=5
#       percept={'price': 266, 'instock': 6}
# i=6 action={'buy': 5}
# i=6 used=3
#       percept={'price': 254, 'instock': 8}
# i=7 action={'buy': 5}
# i=7 used=4
#       percept={'price': 211, 'instock': 9}
# i=8 action={'buy': 5}
# i=8 used=4
#       percept={'price': 212, 'instock': 10}
# i=9 action={'buy': 0}
# i=9 used=4
#       percept={'price': 208, 'instock': 6}
# i=10 action={'buy': 5}
# i=10 used=6
#       percept={'price': 209, 'instock': 5}
# i=11 action={'buy': 5}
# i=11 used=3
#       percept={'price': 237, 'instock': 7}
# i=12 action={'buy': 5}
# i=12 used=1
#       percept={'price': 233, 'instock': 11}
# i=13 action={'buy': 0}
# i=13 used=3
#       percept={'price': 239, 'instock': 8}
# i=14 action={'buy': 5}
# i=14 used=1
#       percept={'price': 236, 'instock': 12}
# i=15 action={'buy': 0}
# i=15 used=4
#       percept={'price': 236, 'instock': 8}
# i=16 action={'buy': 5}
# i=16 used=1
#       percept={'price': 245, 'instock': 12}
# i=17 action={'buy': 0}
# i=17 used=6
#       percept={'price': 245, 'instock': 6}
# i=18 action={'buy': 5}
# i=18 used=3
#       percept={'price': 242, 'instock': 8}
# i=19 action={'buy': 5}
# i=19 used=2
#       percept={'price': 250, 'instock': 11}
# i=20 action={'buy': 0}
# i=20 used=3
#       percept={'price': 243, 'instock': 8}
# i=21 action={'buy': 5}
# i=21 used=3
#       percept={'price': 221, 'instock': 10}
# i=22 action={'buy': 0}
# i=22 used=1
#       percept={'price': 217, 'instock': 9}
# i=23 action={'buy': 5}
# i=23 used=5
#       percept={'price': 223, 'instock': 9}
# i=24 action={'buy': 5}
# i=24 used=2
#       percept={'price': 231, 'instock': 12}
# i=25 action={'buy': 0}
# i=25 used=1
#       percept={'price': 226, 'instock': 11}
# i=26 action={'buy': 0}
# i=26 used=2
#       percept={'price': 226, 'instock': 9}
# i=27 action={'buy': 5}
# i=27 used=6
#       percept={'price': 115, 'instock': 8}
# i=28 action={'buy': 15}
# i=28 used=3
#       percept={'price': 121, 'instock': 20}
# i=29 action={'buy': 15}
# i=29 used=1
#       percept={'price': 233, 'instock': 34}
# i=30 action={'buy': 0}
# i=30 used=2
#       percept={'price': 233, 'instock': 32}
# i=31 action={'buy': 0}
# i=31 used=3
#       percept={'price': 237, 'instock': 29}
# i=32 action={'buy': 0}
# i=32 used=3
#       percept={'price': 247, 'instock': 26}
# i=33 action={'buy': 0}
# i=33 used=2
#       percept={'price': 228, 'instock': 24}
# i=34 action={'buy': 0}
# i=34 used=1
#       percept={'price': 235, 'instock': 23}
# i=35 action={'buy': 0}
# i=35 used=4
#       percept={'price': 248, 'instock': 19}
# i=36 action={'buy': 0}
# i=36 used=3
#       percept={'price': 246, 'instock': 16}
# i=37 action={'buy': 0}
# i=37 used=4
#       percept={'price': 251, 'instock': 12}
# i=38 action={'buy': 0}
# i=38 used=3
#       percept={'price': 265, 'instock': 9}
# i=39 action={'buy': 5}
# i=39 used=6
#       percept={'price': 264, 'instock': 8}
# i=40 action={'buy': 5}
# i=40 used=2
#       percept={'price': 268, 'instock': 11}
# i=41 action={'buy': 0}
# i=41 used=1
#       percept={'price': 278, 'instock': 10}
# i=42 action={'buy': 0}
# i=42 used=1
#       percept={'price': 270, 'instock': 9}
# i=43 action={'buy': 5}
# i=43 used=2
#       percept={'price': 214, 'instock': 12}
# i=44 action={'buy': 0}
# i=44 used=3
#       percept={'price': 216, 'instock': 9}
# i=45 action={'buy': 5}
# i=45 used=3
#       percept={'price': 254, 'instock': 11}
# i=46 action={'buy': 0}
# i=46 used=2
#       percept={'price': 260, 'instock': 9}
# i=47 action={'buy': 5}
# i=47 used=1
#       percept={'price': 265, 'instock': 13}
# i=48 action={'buy': 0}
# i=48 used=4
#       percept={'price': 266, 'instock': 9}
# i=49 action={'buy': 5}
# i=49 used=6
#       percept={'price': 263, 'instock': 8}
# i=50 action={'buy': 5}
# i=50 used=3
#       percept={'price': 261, 'instock': 10}
# i=51 action={'buy': 0}
# i=51 used=2
#       percept={'price': 267, 'instock': 8}
# i=52 action={'buy': 5}
# i=52 used=5
#       percept={'price': 272, 'instock': 8}
# i=53 action={'buy': 5}
# i=53 used=4
#       percept={'price': 273, 'instock': 9}
# i=54 action={'buy': 5}
# i=54 used=3
#       percept={'price': 271, 'instock': 11}
# i=55 action={'buy': 0}
# i=55 used=2
#       percept={'price': 206, 'instock': 9}
# i=56 action={'buy': 5}
# i=56 used=1
#       percept={'price': 265, 'instock': 13}
# i=57 action={'buy': 0}
# i=57 used=3
#       percept={'price': 263, 'instock': 10}
# i=58 action={'buy': 0}
# i=58 used=3
#       percept={'price': 258, 'instock': 7}
# i=59 action={'buy': 5}
# i=59 used=6
#       percept={'price': 257, 'instock': 6}
# i=60 action={'buy': 5}
# i=60 used=5
#       percept={'price': 263, 'instock': 6}
# i=61 action={'buy': 5}
# i=61 used=4
#       percept={'price': 256, 'instock': 7}
# i=62 action={'buy': 5}
# i=62 used=3
#       percept={'price': 259, 'instock': 9}
# i=63 action={'buy': 5}
# i=63 used=4
#       percept={'price': 254, 'instock': 10}
# i=64 action={'buy': 0}
# i=64 used=5
#       percept={'price': 264, 'instock': 5}
# i=65 action={'buy': 5}
# i=65 used=1
#       percept={'price': 265, 'instock': 9}
# i=66 action={'buy': 5}
# i=66 used=1
#       percept={'price': 265, 'instock': 13}
# i=67 action={'buy': 0}
# i=67 used=3
#       percept={'price': 266, 'instock': 10}
# i=68 action={'buy': 0}
# i=68 used=6
#       percept={'price': 268, 'instock': 4}
# i=69 action={'buy': 5}
# i=69 used=4
#       percept={'price': 290, 'instock': 5}
# i=70 action={'buy': 5}
# i=70 used=5
#       percept={'price': 301, 'instock': 5}
# i=71 action={'buy': 5}
# i=71 used=3
#       percept={'price': 306, 'instock': 7}
# i=72 action={'buy': 5}
# i=72 used=4
#       percept={'price': 300, 'instock': 8}
# i=73 action={'buy': 5}
# i=73 used=2
#       percept={'price': 227, 'instock': 11}
# i=74 action={'buy': 0}
# i=74 used=1
#       percept={'price': 230, 'instock': 10}
# i=75 action={'buy': 0}
# i=75 used=2
#       percept={'price': 233, 'instock': 8}
# i=76 action={'buy': 5}
# i=76 used=2
#       percept={'price': 252, 'instock': 11}
# i=77 action={'buy': 0}
# i=77 used=5
#       percept={'price': 254, 'instock': 6}
# i=78 action={'buy': 5}
# i=78 used=2
#       percept={'price': 254, 'instock': 9}
# i=79 action={'buy': 5}
# i=79 used=5
#       percept={'price': 247, 'instock': 9}
# i=80 action={'buy': 5}
# i=80 used=3
#       percept={'price': 220, 'instock': 11}
# i=81 action={'buy': 0}
# i=81 used=3
#       percept={'price': 224, 'instock': 8}
# i=82 action={'buy': 5}
# i=82 used=2
#       percept={'price': 305, 'instock': 11}
# i=83 action={'buy': 0}
# i=83 used=6
#       percept={'price': 302, 'instock': 5}
# i=84 action={'buy': 5}
# i=84 used=4
#       percept={'price': 258, 'instock': 6}
# i=85 action={'buy': 5}
# i=85 used=6
#       percept={'price': 260, 'instock': 5}
# i=86 action={'buy': 5}
# i=86 used=1
#       percept={'price': 269, 'instock': 9}
# i=87 action={'buy': 5}
# i=87 used=5
#       percept={'price': 269, 'instock': 9}
# i=88 action={'buy': 5}
# i=88 used=2
#       percept={'price': 279, 'instock': 12}
# i=89 action={'buy': 0}
# i=89 used=1
#       percept={'price': 278, 'instock': 11}
# i=90 action={'buy': 0}
# i=90 used=3
#       percept={'price': 287, 'instock': 8}
# i=91 action={'buy': 5}
# i=91 used=4
#       percept={'price': 296, 'instock': 9}
# i=92 action={'buy': 5}
# i=92 used=1
#       percept={'price': 297, 'instock': 13}
# i=93 action={'buy': 0}
# i=93 used=1
#       percept={'price': 301, 'instock': 12}
# i=94 action={'buy': 0}
# i=94 used=2
#       percept={'price': 299, 'instock': 10}
# i=95 action={'buy': 0}
# i=95 used=4
#       percept={'price': 305, 'instock': 6}
# i=96 action={'buy': 5}
# i=96 used=1
#       percept={'price': 306, 'instock': 10}
# i=97 action={'buy': 0}
# i=97 used=1
#       percept={'price': 313, 'instock': 9}
# i=98 action={'buy': 5}
# i=98 used=1
#       percept={'price': 293, 'instock': 13}
# i=99 action={'buy': 0}
# i=99 used=1
#       percept={'price': 291, 'instock': 12}

# %%
sim.go(100);
print(f"agent spent ${ag.spent/100}")
pl = Plot_history(ag,env); pl.plot_env_hist(); pl.plot_agent_hist()
# Out:
# i=0 action={'buy': 0}
# i=0 used=3
#       percept={'price': 290, 'instock': 9}
# i=1 action={'buy': 5}
# i=1 used=2
#       percept={'price': 285, 'instock': 12}
# i=2 action={'buy': 0}
# i=2 used=3
#       percept={'price': 288, 'instock': 9}
# i=3 action={'buy': 5}
# i=3 used=3
#       percept={'price': 295, 'instock': 11}
# i=4 action={'buy': 0}
# i=4 used=1
#       percept={'price': 182, 'instock': 10}
# i=5 action={'buy': 15}
# i=5 used=4
#       percept={'price': 187, 'instock': 21}
# i=6 action={'buy': 15}
# i=6 used=3
#       percept={'price': 299, 'instock': 33}
# i=7 action={'buy': 0}
# i=7 used=5
#       percept={'price': 304, 'instock': 28}
# i=8 action={'buy': 0}
# i=8 used=2
#       percept={'price': 317, 'instock': 26}
# i=9 action={'buy': 0}
# i=9 used=3
#       percept={'price': 317, 'instock': 23}
# i=10 action={'buy': 0}
# i=10 used=2
#       percept={'price': 294, 'instock': 21}
# i=11 action={'buy': 0}
# i=11 used=1
#       percept={'price': 296, 'instock': 20}
# i=12 action={'buy': 0}
# i=12 used=2
#       percept={'price': 294, 'instock': 18}
# i=13 action={'buy': 0}
# i=13 used=3
#       percept={'price': 293, 'instock': 15}
# i=14 action={'buy': 0}
# i=14 used=1
#       percept={'price': 302, 'instock': 14}
# i=15 action={'buy': 0}
# i=15 used=3
#       percept={'price': 296, 'instock': 11}
# i=16 action={'buy': 0}
# i=16 used=1
#       percept={'price': 306, 'instock': 10}
# i=17 action={'buy': 0}
# i=17 used=3
#       percept={'price': 310, 'instock': 7}
# i=18 action={'buy': 5}
# i=18 used=3
#       percept={'price': 314, 'instock': 9}
# i=19 action={'buy': 5}
# i=19 used=5
#       percept={'price': 320, 'instock': 9}
# i=20 action={'buy': 5}
# i=20 used=3
#       percept={'price': 256, 'instock': 11}
# i=21 action={'buy': 0}
# i=21 used=2
#       percept={'price': 255, 'instock': 9}
# i=22 action={'buy': 5}
# i=22 used=3
#       percept={'price': 290, 'instock': 11}
# i=23 action={'buy': 0}
# i=23 used=3
#       percept={'price': 287, 'instock': 8}
# i=24 action={'buy': 5}
# i=24 used=3
#       percept={'price': 291, 'instock': 10}
# i=25 action={'buy': 0}
# i=25 used=2
#       percept={'price': 297, 'instock': 8}
# i=26 action={'buy': 5}
# i=26 used=3
#       percept={'price': 301, 'instock': 10}
# i=27 action={'buy': 0}
# i=27 used=1
#       percept={'price': 311, 'instock': 9}
# i=28 action={'buy': 5}
# i=28 used=1
#       percept={'price': 314, 'instock': 13}
# i=29 action={'buy': 0}
# i=29 used=3
#       percept={'price': 319, 'instock': 10}
# i=30 action={'buy': 0}
# i=30 used=2
#       percept={'price': 320, 'instock': 8}
# i=31 action={'buy': 5}
# i=31 used=2
#       percept={'price': 320, 'instock': 11}
# i=32 action={'buy': 0}
# i=32 used=3
#       percept={'price': 255, 'instock': 8}
# i=33 action={'buy': 5}
# i=33 used=4
#       percept={'price': 315, 'instock': 9}
# i=34 action={'buy': 5}
# i=34 used=4
#       percept={'price': 320, 'instock': 10}
# i=35 action={'buy': 0}
# i=35 used=3
#       percept={'price': 339, 'instock': 7}
# i=36 action={'buy': 5}
# i=36 used=3
#       percept={'price': 337, 'instock': 9}
# i=37 action={'buy': 5}
# i=37 used=4
#       percept={'price': 338, 'instock': 10}
# i=38 action={'buy': 0}
# i=38 used=1
#       percept={'price': 331, 'instock': 9}
# i=39 action={'buy': 5}
# i=39 used=1
#       percept={'price': 328, 'instock': 13}
# i=40 action={'buy': 0}
# i=40 used=3
#       percept={'price': 327, 'instock': 10}
# i=41 action={'buy': 0}
# i=41 used=3
#       percept={'price': 335, 'instock': 7}
# i=42 action={'buy': 5}
# i=42 used=6
#       percept={'price': 340, 'instock': 6}
# i=43 action={'buy': 5}
# i=43 used=2
#       percept={'price': 343, 'instock': 9}
# i=44 action={'buy': 5}
# i=44 used=4
#       percept={'price': 329, 'instock': 10}
# i=45 action={'buy': 0}
# i=45 used=3
#       percept={'price': 322, 'instock': 7}
# i=46 action={'buy': 5}
# i=46 used=2
#       percept={'price': 340, 'instock': 10}
# i=47 action={'buy': 0}
# i=47 used=2
#       percept={'price': 335, 'instock': 8}
# i=48 action={'buy': 5}
# i=48 used=2
#       percept={'price': 356, 'instock': 11}
# i=49 action={'buy': 0}
# i=49 used=3
#       percept={'price': 359, 'instock': 8}
# i=50 action={'buy': 5}
# i=50 used=2
#       percept={'price': 299, 'instock': 11}
# i=51 action={'buy': 0}
# i=51 used=6
#       percept={'price': 299, 'instock': 5}
# i=52 action={'buy': 5}
# i=52 used=1
#       percept={'price': 294, 'instock': 9}
# i=53 action={'buy': 5}
# i=53 used=1
#       percept={'price': 312, 'instock': 13}
# i=54 action={'buy': 0}
# i=54 used=4
#       percept={'price': 311, 'instock': 9}
# i=55 action={'buy': 5}
# i=55 used=1
#       percept={'price': 320, 'instock': 13}
# i=56 action={'buy': 0}
# i=56 used=5
#       percept={'price': 327, 'instock': 8}
# i=57 action={'buy': 5}
# i=57 used=6
#       percept={'price': 285, 'instock': 7}
# i=58 action={'buy': 5}
# i=58 used=5
#       percept={'price': 287, 'instock': 7}
# i=59 action={'buy': 5}
# i=59 used=1
#       percept={'price': 356, 'instock': 11}
# i=60 action={'buy': 0}
# i=60 used=4
#       percept={'price': 357, 'instock': 7}
# i=61 action={'buy': 5}
# i=61 used=2
#       percept={'price': 313, 'instock': 10}
# i=62 action={'buy': 0}
# i=62 used=1
#       percept={'price': 313, 'instock': 9}
# i=63 action={'buy': 5}
# i=63 used=4
#       percept={'price': 311, 'instock': 10}
# i=64 action={'buy': 0}
# i=64 used=3
#       percept={'price': 316, 'instock': 7}
# i=65 action={'buy': 5}
# i=65 used=4
#       percept={'price': 337, 'instock': 8}
# i=66 action={'buy': 5}
# i=66 used=1
#       percept={'price': 333, 'instock': 12}
# i=67 action={'buy': 0}
# i=67 used=5
#       percept={'price': 336, 'instock': 7}
# i=68 action={'buy': 5}
# i=68 used=1
#       percept={'price': 334, 'instock': 11}
# i=69 action={'buy': 0}
# i=69 used=4
#       percept={'price': 340, 'instock': 7}
# i=70 action={'buy': 5}
# i=70 used=5
#       percept={'price': 344, 'instock': 7}
# i=71 action={'buy': 5}
# i=71 used=1
#       percept={'price': 339, 'instock': 11}
# i=72 action={'buy': 0}
# i=72 used=2
#       percept={'price': 347, 'instock': 9}
# i=73 action={'buy': 5}
# i=73 used=3
#       percept={'price': 356, 'instock': 11}
# i=74 action={'buy': 0}
# i=74 used=3
#       percept={'price': 359, 'instock': 8}
# i=75 action={'buy': 5}
# i=75 used=2
#       percept={'price': 345, 'instock': 11}
# i=76 action={'buy': 0}
# i=76 used=2
#       percept={'price': 350, 'instock': 9}
# i=77 action={'buy': 5}
# i=77 used=2
#       percept={'price': 368, 'instock': 12}
# i=78 action={'buy': 0}
# i=78 used=1
#       percept={'price': 365, 'instock': 11}
# i=79 action={'buy': 0}
# i=79 used=3
#       percept={'price': 365, 'instock': 8}
# i=80 action={'buy': 5}
# i=80 used=2
#       percept={'price': 365, 'instock': 11}
# i=81 action={'buy': 0}
# i=81 used=5
#       percept={'price': 261, 'instock': 6}
# i=82 action={'buy': 5}
# i=82 used=4
#       percept={'price': 257, 'instock': 7}
# i=83 action={'buy': 5}
# i=83 used=1
#       percept={'price': 366, 'instock': 11}
# i=84 action={'buy': 0}
# i=84 used=2
#       percept={'price': 363, 'instock': 9}
# i=85 action={'buy': 5}
# i=85 used=2
#       percept={'price': 359, 'instock': 12}
# i=86 action={'buy': 0}
# i=86 used=6
#       percept={'price': 360, 'instock': 6}
# i=87 action={'buy': 5}
# i=87 used=5
#       percept={'price': 350, 'instock': 6}
# i=88 action={'buy': 5}
# i=88 used=6
#       percept={'price': 344, 'instock': 5}
# i=89 action={'buy': 5}
# i=89 used=4
#       percept={'price': 351, 'instock': 6}
# i=90 action={'buy': 5}
# i=90 used=2
#       percept={'price': 346, 'instock': 9}
# i=91 action={'buy': 5}
# i=91 used=6
#       percept={'price': 354, 'instock': 8}
# i=92 action={'buy': 5}
# i=92 used=2
#       percept={'price': 358, 'instock': 11}
# i=93 action={'buy': 0}
# i=93 used=2
#       percept={'price': 366, 'instock': 9}
# i=94 action={'buy': 5}
# i=94 used=1
#       percept={'price': 370, 'instock': 13}
# i=95 action={'buy': 0}
# i=95 used=3
#       percept={'price': 391, 'instock': 10}
# i=96 action={'buy': 0}
# i=96 used=5
#       percept={'price': 391, 'instock': 5}
# i=97 action={'buy': 5}
# i=97 used=6
#       percept={'price': 339, 'instock': 4}
# i=98 action={'buy': 5}
# i=98 used=1
#       percept={'price': 339, 'instock': 8}
# i=99 action={'buy': 5}
# i=99 used=6
#       percept={'price': 395, 'instock': 7}
# agent spent $1656.6

# %% [markdown]
# # **Task 2**
#
# # Trading Agent for Smartphone Inventory Management:
#
# **Percepts**:
#
# The agent receives two percepts:
#
# * **Price:** The current price of a specific smartphone model.
# * **Amount in Stock:** The quantity of that smartphone model available in the store.
#
# **Decision Process:**
#
# * The agent’s goal is to optimize stock levels while minimizing costs.
# * It must decide whether to order more smartphones and, if so, how many to order.
#
# **Decision Rules:**
# * If the price of the smartphone drops significantly (indicating a deal or promotion), the agent considers ordering more units.
#
# **Threshold:** Let’s say the threshold is a 20% discount from the average price.
#
# * If the amount in stock falls below a certain level (e.g., 10 units), the agent prioritizes restocking.
# * Otherwise, the agent decides not to place an order.
#
# **Actions:**
#
# * If the smartphone price is below the threshold (20% discount) and the stock level is not critically low, the agent orders a specific quantity (let’s call it tobuy).
#
#
# > **Example:** If the smartphone price drops to 500 BDT (from an average of 600 BDT) and there are 20 units in stock, the agent might decide to order 15 more units.
#
#
# * If the stock level is critically low (e.g., less than 10), the agent orders a minimum quantity (e.g., 10 units).
# * Otherwise, if neither condition is met, the agent does not place an order (i.e., tobuy = 0).
#
# **Submition**
# * Submit the code in python file .py not .ipynb.
# * The code should behave like the above and generate a graph as shown in example.

# %% [markdown]
# # **Task 1**
# Modify the existing code to fullfill following condtions
#
# 1.   If the last_price is less than 70% of the average (ave) and the instock quantity is less than 30, then set tobuy to 15.
# 2.   Otherwise, if the instock quantity is less than 10, set tobuy to 5.
# If none of the above conditions apply, set tobuy to 0.
